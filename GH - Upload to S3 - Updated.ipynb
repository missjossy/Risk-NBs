# %% [markdown]
# # Imports

# %%
import boto3

# %%
import pandas as pd
# import mpu

# %%
from mpu import aws

# %%
def list_bucket(bucket_name: str, prefix: str):
    result = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter='/')
    # if result.get('Contents'):
    #     objects = [obj.get('Key') for obj in result.get('Contents') if obj.get('Key')]
    return result

# %% [markdown]
# # Load CSV

# %%
df=pd.read_csv('Ghana - Marketing_Growth 360 Report - 2025 - May 2025 Overview.csv')

# %%
df=df.iloc[:27,:32]
# df=df.iloc[:18,:17]
df
# Out:
#                                  6/3/2025   May 1   May 2   May 3   May 4  \
# 0                            New Installs   3,621   3,480   3,153   2,758
# 1                                 Sign up   3,092   3,004   2,545   2,021
# 2                           KYC Completed   1,583   1,479   1,382   1,029
# 3                             FS_ELIGIBLE     932     918     817     609
# 4                  Survey Submitted (Biz)     161     151     148     107
# 5                     Doc Submitted (Biz)      93      61      62      44
# 6             First Disbursement Personal     881     868     793     600
# 7                  First Disb.FidoBiz New      13      18       8       0
# 8        First Disb. Biz New Partnerships       4       3       2       1
# 9        First Disb. FidoBiz Migrated New      14      69      11       6
# 10  First Disb. Biz Migrated New Partners       0       0       0       0
# 11       First Disb. FidoBiz Migrated Old      49      50      28      21
# 12  First Disb. Biz Migrated Old Partners       2       3       1       1
# 13             First Disbursement All New     898     889     803     601
# 14                            Cost Growth  $3,020  $3,158  $3,074  $3,032
# 15                        Cost Marketing     $503    $503    $503    $503
# 16                                    CAC   $3.92   $4.12   $4.45   $5.88
# 17                                    CPI   $0.97   $1.05   $1.13   $1.28
# 18                                    CPL   $1.14   $1.22   $1.41   $1.75
# 19                                  CPKYC   $2.23   $2.48   $2.59   $3.43
# 20                        Installs/SignUp     85%     86%     81%     73%
# 21                  Sign Up/KYC completed     51%     49%     54%     51%
# 22                        KYC/First Disb.     57%     60%     58%     58%
# 23                         FS/First Disb.     96%     97%     98%     99%
# 24                      Survey/Docs (Biz)     58%     40%     42%     41%
# 25                 New install/ First dis     25%     26%     25%     22%
# 26                      SignUp/First dis.     29%     30%     32%     30%
#
#      May 5   May 6   May 7   May 8   May 9  ...  May 22  May 23  May 24  \
# 0    3,304   3,535   3,390   3,444   3,425  ...   3,650   3,388   3,034
# 1    2,687   2,808   2,630   2,703   2,738  ...   3,038   2,754   2,498
# 2    1,307   1,393   1,409   1,366   1,246  ...   1,575   1,347   1,246
# 3      815     876     859     800     814  ...     995     859     799
# 4      193     196     192     204     177  ...     136     141     114
# 5       73      76      96      90      93  ...     133     108      88
# 6      795     824     803     764     824  ...     912     830     753
# 7        9       8      10       8      13  ...      13      15      10
# 8        1       1       2       4       6  ...       5       6       3
# 9       26      32      29      40      64  ...      29      66      22
# 10       1       1       0       1       0  ...       6       5       3
# 11      30      38      33      32      23  ...      54      48      44
# 12       1       1       1       1       3  ...       1       2       4
# 13     805     833     815     776     843  ...     930     851     766
# 14  $3,262  $3,430  $3,463  $3,435  $3,551  ...  $3,147  $3,080  $3,010
# 15    $503    $503    $503    $503    $503  ...    $503    $503    $503
# 16   $4.68   $4.72   $4.87   $5.07   $4.81  ...   $3.92   $4.21   $4.59
# 17   $1.14   $1.11   $1.17   $1.14   $1.18  ...   $1.00   $1.06   $1.16
# 18   $1.40   $1.40   $1.51   $1.46   $1.48  ...   $1.20   $1.30   $1.41
# 19   $2.88   $2.82   $2.81   $2.88   $3.25  ...   $2.32   $2.66   $2.82
# 20     81%     79%     78%     78%     80%  ...     83%     81%     82%
# 21     49%     50%     54%     51%     46%  ...     52%     49%     50%
# 22     62%     60%     58%     57%     68%  ...     59%     63%     61%
# 23     99%     95%     95%     97%    104%  ...     93%     99%     96%
# 24     38%     39%     50%     44%     53%  ...     98%     77%     77%
# 25     24%     24%     24%     23%     25%  ...     25%     25%     25%
# 26     30%     30%     31%     29%     31%  ...     31%     31%     31%
#
#     May 25  May 26  May 27  May 28  May 29  May 30  May 31
# 0    2,877   3,249   3,480   3,469   3,235   3,499   2,984
# 1    2,364   2,774   2,927   2,929   2,730   2,794   2,372
# 2    1,124   1,456   1,520   1,464   1,434   1,530   1,280
# 3      723     908     877     940     895     948     235
# 4       88     147     319     420     338     282     278
# 5       95      98     135     148     133      98     123
# 6      686     865     850     883     809     864     766
# 7        3      12      10      15      11      11      11
# 8        2       3       6       6       3       3       4
# 9       16      29      43      22      23      67      14
# 10       1       7      10       4       5       7       1
# 11      30      62      82      65      51      81      45
# 12       4       7      15      12       7      13       5
# 13     691     880     866     904     823     878     781
# 14  $2,953  $3,060  $3,026  $3,051  $2,964  $2,916  $2,716
# 15    $503    $503    $503    $503    $503    $503    $503
# 16   $5.00   $4.05   $4.07   $3.93   $4.21   $3.89   $4.12
# 17   $1.20   $1.10   $1.01   $1.02   $1.07   $0.98   $1.08
# 18   $1.46   $1.28   $1.21   $1.21   $1.27   $1.22   $1.36
# 19   $3.07   $2.45   $2.32   $2.43   $2.42   $2.23   $2.51
# 20     82%     85%     84%     84%     84%     80%     79%
# 21     48%     52%     52%     50%     53%     55%     54%
# 22     61%     60%     57%     62%     57%     57%     61%
# 23     96%     97%     99%     96%     92%     93%    332%
# 24    108%     67%     42%     35%     39%     35%     44%
# 25     24%     27%     25%     26%     25%     25%     26%
# 26     29%     32%     30%     31%     30%     31%     33%
#
# [27 rows x 32 columns]

# %% [markdown]
# ### edit

# %%
new_column_names = df.columns.tolist()
df.columns = range(len(df.columns))

# %%
# Insert a new row at the beginning with the original column names
df.loc[-1] = new_column_names

# %%
df.index = df.index + 1

# %%
df=df.sort_index().transpose()
df.columns = df.iloc[0]
df = df[1:]
df = df.rename(columns={'Cost Growth': 'Cost Digital', 'Cost Marketing ': 'Cost offline '})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace(r'[+\-./]', '', regex=True)
df
# Out:
# 0   632025 new_installs sign_up kyc_completed fs_eligible  \
# 1    May 1        3,621   3,092         1,583         932
# 2    May 2        3,480   3,004         1,479         918
# 3    May 3        3,153   2,545         1,382         817
# 4    May 4        2,758   2,021         1,029         609
# 5    May 5        3,304   2,687         1,307         815
# 6    May 6        3,535   2,808         1,393         876
# 7    May 7        3,390   2,630         1,409         859
# 8    May 8        3,444   2,703         1,366         800
# 9    May 9        3,425   2,738         1,246         814
# 10  May 10        3,062   2,471         1,260         799
# 11  May 11        2,675   2,038           966         578
# 12  May 12        3,376   2,599         1,325         818
# 13  May 13        3,357   2,808         1,417         925
# 14  May 14        3,396   2,832         1,398         867
# 15  May 15        3,264   2,781         1,484         929
# 16  May 16        3,387   2,744         1,406         868
# 17  May 17        2,936   2,390         1,277         804
# 18  May 18        2,831   2,220         1,135         727
# 19  May 19        3,357   2,966         1,477         947
# 20  May 20        3,546   2,916         1,530         867
# 21  May 21        3,622   3,056         1,534        1008
# 22  May 22        3,650   3,038         1,575         995
# 23  May 23        3,388   2,754         1,347         859
# 24  May 24        3,034   2,498         1,246         799
# 25  May 25        2,877   2,364         1,124         723
# 26  May 26        3,249   2,774         1,456         908
# 27  May 27        3,480   2,927         1,520         877
# 28  May 28        3,469   2,929         1,464         940
# 29  May 29        3,235   2,730         1,434         895
# 30  May 30        3,499   2,794         1,530         948
# 31  May 31        2,984   2,372         1,280         235
#
# 0  survey_submitted_(biz) doc_submitted_(biz) first_disbursement_personal  \
# 1                     161                  93                         881
# 2                     151                  61                         868
# 3                     148                  62                         793
# 4                     107                  44                         600
# 5                     193                  73                         795
# 6                     196                  76                         824
# 7                     192                  96                         803
# 8                     204                  90                         764
# 9                     177                  93                         824
# 10                    208                  87                         749
# 11                    140                  68                         566
# 12                    192                  70                         777
# 13                    240                 106                         863
# 14                    227                  86                         827
# 15                    244                 118                         837
# 16                    259                 130                         868
# 17                    217                  87                         748
# 18                    135                  87                         710
# 19                    143                  96                         871
# 20                    128                 132                         854
# 21                    136                 137                         918
# 22                    136                 133                         912
# 23                    141                 108                         830
# 24                    114                  88                         753
# 25                     88                  95                         686
# 26                    147                  98                         865
# 27                    319                 135                         850
# 28                    420                 148                         883
# 29                    338                 133                         809
# 30                    282                  98                         864
# 31                    278                 123                         766
#
# 0  first_disbfidobiz_new first_disb_biz_new_partnerships  ...    cpi    cpl  \
# 1                     13                               4  ...  $0.97  $1.14
# 2                     18                               3  ...  $1.05  $1.22
# 3                      8                               2  ...  $1.13  $1.41
# 4                      0                               1  ...  $1.28  $1.75
# 5                      9                               1  ...  $1.14  $1.40
# 6                      8                               1  ...  $1.11  $1.40
# 7                     10                               2  ...  $1.17  $1.51
# 8                      8                               4  ...  $1.14  $1.46
# 9                     13                               6  ...  $1.18  $1.48
# 10                     7                               0  ...  $1.27  $1.57
# 11                     8                               0  ...  $1.41  $1.86
# 12                    13                               1  ...  $1.22  $1.58
# 13                    14                               0  ...  $1.14  $1.36
# 14                    10                               4  ...  $1.13  $1.35
# 15                    11                               4  ...  $1.13  $1.33
# 16                    13                               2  ...  $1.09  $1.35
# 17                     9                               4  ...  $1.21  $1.49
# 18                     8                               2  ...  $1.22  $1.56
# 19                     8                               6  ...  $1.07  $1.21
# 20                    14                               4  ...  $1.05  $1.28
# 21                    15                               2  ...  $1.02  $1.21
# 22                    13                               5  ...  $1.00  $1.20
# 23                    15                               6  ...  $1.06  $1.30
# 24                    10                               3  ...  $1.16  $1.41
# 25                     3                               2  ...  $1.20  $1.46
# 26                    12                               3  ...  $1.10  $1.28
# 27                    10                               6  ...  $1.01  $1.21
# 28                    15                               6  ...  $1.02  $1.21
# 29                    11                               3  ...  $1.07  $1.27
# 30                    11                               3  ...  $0.98  $1.22
# 31                    11                               4  ...  $1.08  $1.36
#
# 0   cpkyc installssignup sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1   $2.23            85%                  51%           57%          96%
# 2   $2.48            86%                  49%           60%          97%
# 3   $2.59            81%                  54%           58%          98%
# 4   $3.43            73%                  51%           58%          99%
# 5   $2.88            81%                  49%           62%          99%
# 6   $2.82            79%                  50%           60%          95%
# 7   $2.81            78%                  54%           58%          95%
# 8   $2.88            78%                  51%           57%          97%
# 9   $3.25            80%                  46%           68%         104%
# 10  $3.08            81%                  51%           60%          95%
# 11  $3.92            76%                  47%           59%          99%
# 12  $3.10            77%                  51%           60%          97%
# 13  $2.70            84%                  50%           62%          95%
# 14  $2.74            83%                  49%           60%          97%
# 15  $2.49            85%                  53%           57%          92%
# 16  $2.64            81%                  51%           63%         102%
# 17  $2.78            81%                  53%           60%          95%
# 18  $3.05            78%                  51%           63%          99%
# 19  $2.42            88%                  50%           60%          93%
# 20  $2.44            82%                  52%           57%         101%
# 21  $2.42            84%                  50%           61%          93%
# 22  $2.32            83%                  52%           59%          93%
# 23  $2.66            81%                  49%           63%          99%
# 24  $2.82            82%                  50%           61%          96%
# 25  $3.07            82%                  48%           61%          96%
# 26  $2.45            85%                  52%           60%          97%
# 27  $2.32            84%                  52%           57%          99%
# 28  $2.43            84%                  50%           62%          96%
# 29  $2.42            84%                  53%           57%          92%
# 30  $2.23            80%                  55%           57%          93%
# 31  $2.51            79%                  54%           61%         332%
#
# 0  surveydocs_(biz) new_install_first_dis signupfirst_dis
# 1               58%                   25%             29%
# 2               40%                   26%             30%
# 3               42%                   25%             32%
# 4               41%                   22%             30%
# 5               38%                   24%             30%
# 6               39%                   24%             30%
# 7               50%                   24%             31%
# 8               44%                   23%             29%
# 9               53%                   25%             31%
# 10              42%                   25%             31%
# 11              49%                   21%             28%
# 12              36%                   23%             30%
# 13              44%                   26%             31%
# 14              38%                   25%             30%
# 15              48%                   26%             31%
# 16              50%                   26%             32%
# 17              40%                   26%             32%
# 18              64%                   25%             32%
# 19              67%                   26%             30%
# 20             103%                   25%             30%
# 21             101%                   26%             31%
# 22              98%                   25%             31%
# 23              77%                   25%             31%
# 24              77%                   25%             31%
# 25             108%                   24%             29%
# 26              67%                   27%             32%
# 27              42%                   25%             30%
# 28              35%                   26%             31%
# 29              39%                   25%             30%
# 30              35%                   25%             31%
# 31              44%                   26%             33%
#
# [31 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['632025', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'survey_submitted_(biz)', 'doc_submitted_(biz)',
#        'first_disbursement_personal', 'first_disbfidobiz_new',
#        'first_disb_biz_new_partnerships', 'first_disb_fidobiz_migrated_new',
#        'first_disb_biz_migrated_new_partners',
#        'first_disb_fidobiz_migrated_old',
#        'first_disb_biz_migrated_old_partners', 'first_disbursement_all_new',
#        'cost_digital', 'cost_offline_', 'cac', 'cpi', 'cpl', 'cpkyc',
#        'installssignup', 'sign_upkyc_completed', 'kycfirst_disb',
#        'fsfirst_disb', 'surveydocs_(biz)', 'new_install_first_dis',
#        'signupfirst_dis'],
#       dtype='object', name=0)

# %%
import numpy as np

# %%
df.columns = ['report_day'] + df.columns.tolist()[1:]
df['report_day'] = pd.to_datetime(df['report_day'], format='%B %d')
df['report_day'] = df['report_day'].dt.strftime('2025-%m-%d')
df
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 1   2025-05-01        3,621   3,092         1,583         932
# 2   2025-05-02        3,480   3,004         1,479         918
# 3   2025-05-03        3,153   2,545         1,382         817
# 4   2025-05-04        2,758   2,021         1,029         609
# 5   2025-05-05        3,304   2,687         1,307         815
# 6   2025-05-06        3,535   2,808         1,393         876
# 7   2025-05-07        3,390   2,630         1,409         859
# 8   2025-05-08        3,444   2,703         1,366         800
# 9   2025-05-09        3,425   2,738         1,246         814
# 10  2025-05-10        3,062   2,471         1,260         799
# 11  2025-05-11        2,675   2,038           966         578
# 12  2025-05-12        3,376   2,599         1,325         818
# 13  2025-05-13        3,357   2,808         1,417         925
# 14  2025-05-14        3,396   2,832         1,398         867
# 15  2025-05-15        3,264   2,781         1,484         929
# 16  2025-05-16        3,387   2,744         1,406         868
# 17  2025-05-17        2,936   2,390         1,277         804
# 18  2025-05-18        2,831   2,220         1,135         727
# 19  2025-05-19        3,357   2,966         1,477         947
# 20  2025-05-20        3,546   2,916         1,530         867
# 21  2025-05-21        3,622   3,056         1,534        1008
# 22  2025-05-22        3,650   3,038         1,575         995
# 23  2025-05-23        3,388   2,754         1,347         859
# 24  2025-05-24        3,034   2,498         1,246         799
# 25  2025-05-25        2,877   2,364         1,124         723
# 26  2025-05-26        3,249   2,774         1,456         908
# 27  2025-05-27        3,480   2,927         1,520         877
# 28  2025-05-28        3,469   2,929         1,464         940
# 29  2025-05-29        3,235   2,730         1,434         895
# 30  2025-05-30        3,499   2,794         1,530         948
# 31  2025-05-31        2,984   2,372         1,280         235
#
#    survey_submitted_(biz) doc_submitted_(biz) first_disbursement_personal  \
# 1                     161                  93                         881
# 2                     151                  61                         868
# 3                     148                  62                         793
# 4                     107                  44                         600
# 5                     193                  73                         795
# 6                     196                  76                         824
# 7                     192                  96                         803
# 8                     204                  90                         764
# 9                     177                  93                         824
# 10                    208                  87                         749
# 11                    140                  68                         566
# 12                    192                  70                         777
# 13                    240                 106                         863
# 14                    227                  86                         827
# 15                    244                 118                         837
# 16                    259                 130                         868
# 17                    217                  87                         748
# 18                    135                  87                         710
# 19                    143                  96                         871
# 20                    128                 132                         854
# 21                    136                 137                         918
# 22                    136                 133                         912
# 23                    141                 108                         830
# 24                    114                  88                         753
# 25                     88                  95                         686
# 26                    147                  98                         865
# 27                    319                 135                         850
# 28                    420                 148                         883
# 29                    338                 133                         809
# 30                    282                  98                         864
# 31                    278                 123                         766
#
#    first_disbfidobiz_new first_disb_biz_new_partnerships  ...    cpi    cpl  \
# 1                     13                               4  ...  $0.97  $1.14
# 2                     18                               3  ...  $1.05  $1.22
# 3                      8                               2  ...  $1.13  $1.41
# 4                      0                               1  ...  $1.28  $1.75
# 5                      9                               1  ...  $1.14  $1.40
# 6                      8                               1  ...  $1.11  $1.40
# 7                     10                               2  ...  $1.17  $1.51
# 8                      8                               4  ...  $1.14  $1.46
# 9                     13                               6  ...  $1.18  $1.48
# 10                     7                               0  ...  $1.27  $1.57
# 11                     8                               0  ...  $1.41  $1.86
# 12                    13                               1  ...  $1.22  $1.58
# 13                    14                               0  ...  $1.14  $1.36
# 14                    10                               4  ...  $1.13  $1.35
# 15                    11                               4  ...  $1.13  $1.33
# 16                    13                               2  ...  $1.09  $1.35
# 17                     9                               4  ...  $1.21  $1.49
# 18                     8                               2  ...  $1.22  $1.56
# 19                     8                               6  ...  $1.07  $1.21
# 20                    14                               4  ...  $1.05  $1.28
# 21                    15                               2  ...  $1.02  $1.21
# 22                    13                               5  ...  $1.00  $1.20
# 23                    15                               6  ...  $1.06  $1.30
# 24                    10                               3  ...  $1.16  $1.41
# 25                     3                               2  ...  $1.20  $1.46
# 26                    12                               3  ...  $1.10  $1.28
# 27                    10                               6  ...  $1.01  $1.21
# 28                    15                               6  ...  $1.02  $1.21
# 29                    11                               3  ...  $1.07  $1.27
# 30                    11                               3  ...  $0.98  $1.22
# 31                    11                               4  ...  $1.08  $1.36
#
#     cpkyc installssignup sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1   $2.23            85%                  51%           57%          96%
# 2   $2.48            86%                  49%           60%          97%
# 3   $2.59            81%                  54%           58%          98%
# 4   $3.43            73%                  51%           58%          99%
# 5   $2.88            81%                  49%           62%          99%
# 6   $2.82            79%                  50%           60%          95%
# 7   $2.81            78%                  54%           58%          95%
# 8   $2.88            78%                  51%           57%          97%
# 9   $3.25            80%                  46%           68%         104%
# 10  $3.08            81%                  51%           60%          95%
# 11  $3.92            76%                  47%           59%          99%
# 12  $3.10            77%                  51%           60%          97%
# 13  $2.70            84%                  50%           62%          95%
# 14  $2.74            83%                  49%           60%          97%
# 15  $2.49            85%                  53%           57%          92%
# 16  $2.64            81%                  51%           63%         102%
# 17  $2.78            81%                  53%           60%          95%
# 18  $3.05            78%                  51%           63%          99%
# 19  $2.42            88%                  50%           60%          93%
# 20  $2.44            82%                  52%           57%         101%
# 21  $2.42            84%                  50%           61%          93%
# 22  $2.32            83%                  52%           59%          93%
# 23  $2.66            81%                  49%           63%          99%
# 24  $2.82            82%                  50%           61%          96%
# 25  $3.07            82%                  48%           61%          96%
# 26  $2.45            85%                  52%           60%          97%
# 27  $2.32            84%                  52%           57%          99%
# 28  $2.43            84%                  50%           62%          96%
# 29  $2.42            84%                  53%           57%          92%
# 30  $2.23            80%                  55%           57%          93%
# 31  $2.51            79%                  54%           61%         332%
#
#    surveydocs_(biz) new_install_first_dis signupfirst_dis
# 1               58%                   25%             29%
# 2               40%                   26%             30%
# 3               42%                   25%             32%
# 4               41%                   22%             30%
# 5               38%                   24%             30%
# 6               39%                   24%             30%
# 7               50%                   24%             31%
# 8               44%                   23%             29%
# 9               53%                   25%             31%
# 10              42%                   25%             31%
# 11              49%                   21%             28%
# 12              36%                   23%             30%
# 13              44%                   26%             31%
# 14              38%                   25%             30%
# 15              48%                   26%             31%
# 16              50%                   26%             32%
# 17              40%                   26%             32%
# 18              64%                   25%             32%
# 19              67%                   26%             30%
# 20             103%                   25%             30%
# 21             101%                   26%             31%
# 22              98%                   25%             31%
# 23              77%                   25%             31%
# 24              77%                   25%             31%
# 25             108%                   24%             29%
# 26              67%                   27%             32%
# 27              42%                   25%             30%
# 28              35%                   26%             31%
# 29              39%                   25%             30%
# 30              35%                   25%             31%
# 31              44%                   26%             33%
#
# [31 rows x 28 columns]

# %%
df.head(2)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-05-01        3,621   3,092         1,583         932
# 2  2025-05-02        3,480   3,004         1,479         918
#
#   survey_submitted_(biz) doc_submitted_(biz) first_disbursement_personal  \
# 1                    161                  93                         881
# 2                    151                  61                         868
#
#   first_disbfidobiz_new first_disb_biz_new_partnerships  ...    cpi    cpl  \
# 1                    13                               4  ...  $0.97  $1.14
# 2                    18                               3  ...  $1.05  $1.22
#
#    cpkyc installssignup sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1  $2.23            85%                  51%           57%          96%
# 2  $2.48            86%                  49%           60%          97%
#
#   surveydocs_(biz) new_install_first_dis signupfirst_dis
# 1              58%                   25%             29%
# 2              40%                   26%             30%
#
# [2 rows x 28 columns]

# %%
df['new_install_first_dis']=np.nan
df['signupfirst_dis']=np.nan

# %%
df['cac_incl_branding']=np.nan
df['first_disbursement_all']=np.nan
df['fsfirst_disb']=np.nan
df['first_disbursement_fidobiz']=np.nan

# %%
df.columns
# Out:
# Index(['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'survey_submitted_(biz)', 'doc_submitted_(biz)',
#        'first_disbursement_personal', 'first_disbfidobiz_new',
#        'first_disb_biz_new_partnerships', 'first_disb_fidobiz_migrated_new',
#        'first_disb_biz_migrated_new_partners',
#        'first_disb_fidobiz_migrated_old',
#        'first_disb_biz_migrated_old_partners', 'first_disbursement_all_new',
#        'cost_digital', 'cost_offline_', 'cac', 'cpi', 'cpl', 'cpkyc',
#        'installssignup', 'sign_upkyc_completed', 'kycfirst_disb',
#        'fsfirst_disb', 'surveydocs_(biz)', 'new_install_first_dis',
#        'signupfirst_dis', 'cac_incl_branding', 'first_disbursement_all',
#        'first_disbursement_fidobiz'],
#       dtype='object')

# %%
# List of columns to keep constant
constant_cols = ['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible','first_disbursement_all',
                 'cost_digital', 'cost_offline_', 'cac', 'cac_incl_branding', 'cpi', 'cpl', 'cpkyc', 'installssignup',
                 'sign_upkyc_completed', 'kycfirst_disb','fsfirst_disb',  'new_install_first_dis', 'signupfirst_dis']
added_cols = ['first_disbursement_personal','first_disbursement_fidobiz']

# Identify columns to move (those not in constant_cols)
cols_to_move = [col for col in df.columns if col not in constant_cols]
cols_to_move2 = [col for col in cols_to_move if col not in added_cols]


# Reorganize columns: keep constant columns first, then move the others
df = df[constant_cols + added_cols + cols_to_move2]

# %%
df.head(2)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-05-01        3,621   3,092         1,583         932
# 2  2025-05-02        3,480   3,004         1,479         918
#
#    first_disbursement_all cost_digital cost_offline_    cac  \
# 1                     NaN       $3,020          $503  $3.92
# 2                     NaN       $3,158          $503  $4.12
#
#    cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 1                NaN  ...                    161                  93
# 2                NaN  ...                    151                  61
#
#   first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 1                    13                               4
# 2                    18                               3
#
#   first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 1                              14                                    0
# 2                              69                                    0
#
#    first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 1                               49                                     2
# 2                               50                                     3
#
#    first_disbursement_all_new surveydocs_(biz)
# 1                         898              58%
# 2                         889              40%
#
# [2 rows x 31 columns]

# %%
df['first_disbursement_fidobiz'] = df['first_disbfidobiz_new'].astype(int) + df['first_disb_biz_new_partnerships'].astype(int) 
df['first_disbursement_all'] = df['first_disbursement_personal'].astype(int) + df['first_disbursement_fidobiz'].astype(int)

# %%
df.tail(2)
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 30  2025-05-30        3,499   2,794         1,530         948
# 31  2025-05-31        2,984   2,372         1,280         235
#
#     first_disbursement_all cost_digital cost_offline_    cac  \
# 30                     878       $2,916          $503  $3.89
# 31                     781       $2,716          $503  $4.12
#
#     cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 30                NaN  ...                    282                  98
# 31                NaN  ...                    278                 123
#
#    first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 30                    11                               3
# 31                    11                               4
#
#    first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 30                              67                                    7
# 31                              14                                    1
#
#     first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 30                               81                                    13
# 31                               45                                     5
#
#     first_disbursement_all_new surveydocs_(biz)
# 30                         878              35%
# 31                         781              44%
#
# [2 rows x 31 columns]

# %% [markdown]
# # Upload to S3

# %%
import boto3

# %%
session = boto3.Session(profile_name='gh-dev')

# %%
s3 = session.resource('s3')
my_bucket=s3.Bucket('gh-dev-risk-data')

# %%
df.shape
# Out:
# (31, 31)

# %%
df.head(5)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-05-01        3,621   3,092         1,583         932
# 2  2025-05-02        3,480   3,004         1,479         918
# 3  2025-05-03        3,153   2,545         1,382         817
# 4  2025-05-04        2,758   2,021         1,029         609
# 5  2025-05-05        3,304   2,687         1,307         815
#
#    first_disbursement_all cost_digital cost_offline_    cac  \
# 1                     898       $3,020          $503  $3.92
# 2                     889       $3,158          $503  $4.12
# 3                     803       $3,074          $503  $4.45
# 4                     601       $3,032          $503  $5.88
# 5                     805       $3,262          $503  $4.68
#
#    cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 1                NaN  ...                    161                  93
# 2                NaN  ...                    151                  61
# 3                NaN  ...                    148                  62
# 4                NaN  ...                    107                  44
# 5                NaN  ...                    193                  73
#
#   first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 1                    13                               4
# 2                    18                               3
# 3                     8                               2
# 4                     0                               1
# 5                     9                               1
#
#   first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 1                              14                                    0
# 2                              69                                    0
# 3                              11                                    0
# 4                               6                                    0
# 5                              26                                    1
#
#    first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 1                               49                                     2
# 2                               50                                     3
# 3                               28                                     1
# 4                               21                                     1
# 5                               30                                     1
#
#    first_disbursement_all_new surveydocs_(biz)
# 1                         898              58%
# 2                         889              40%
# 3                         803              42%
# 4                         601              41%
# 5                         805              38%
#
# [5 rows x 31 columns]

# %%
# upload df as csv

from io import StringIO

# Assume df is your DataFrame
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)  # Convert DataFrame to CSV format in-memory

# %%
file_name='gh_cac_may_2025.csv'

# %%
# Create an S3 client
s3_client = session.client('s3')

# Specify the bucket and folder names
bucket_name = 'gh-dev-risk-data'
folder_name = 'cac-reports/'  # The folder you created in S3

# Upload the CSV to S3
s3_client.put_object(
    Bucket=bucket_name,
    Key=f'{folder_name}{file_name}',  # Path in S3 including the folder
    Body=csv_buffer.getvalue()  # Get the CSV data from the buffer
)
# Out:
# {'ResponseMetadata': {'RequestId': '3RQVXSTY9R352BBH',
#   'HostId': 'YFqaJPBiryjHSDSYDyc42b7OpLtiBgyjwAbqXYQcx7j4ZvDsD9u4iTdvpvandoQck1VFuQPGq/HbDEy+SrhGYLgBTNi3HNGK',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'YFqaJPBiryjHSDSYDyc42b7OpLtiBgyjwAbqXYQcx7j4ZvDsD9u4iTdvpvandoQck1VFuQPGq/HbDEy+SrhGYLgBTNi3HNGK',
#    'x-amz-request-id': '3RQVXSTY9R352BBH',
#    'date': 'Tue, 03 Jun 2025 07:38:44 GMT',
#    'x-amz-version-id': 'GV7ZYnwFaGQlsp_mSpoTUQO0czPEfTe1',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"0d28c9faece2f007652f65fd0791a3a0"',
#    'x-amz-checksum-crc64nvme': 'jGWQtuDr2P8=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"0d28c9faece2f007652f65fd0791a3a0"',
#  'ServerSideEncryption': 'AES256',
#  'VersionId': 'GV7ZYnwFaGQlsp_mSpoTUQO0czPEfTe1'}

# %% [markdown]
# # See list of files

# %%
# !/usr/local/bin/aws --profile gh-dev s3 ls s3://'gh-dev-risk-data/cac-reports/'
# Out:
# zsh:1: no such file or directory: /usr/local/bin/aws

# %%
# !/usr/local/bin/aws --profile gh-dev s3 ls s3://'gh-dev-risk-data/fdr-predictions/'
# Out:
# zsh:1: no such file or directory: /usr/local/bin/aws
