# %% [markdown]
# # Imports

# %%
import boto3
import numpy as np

# %%
import pandas as pd
import mpu

# %%
from mpu import aws

# %%
def list_bucket(bucket_name: str, prefix: str):
    result = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter='/')
    # if result.get('Contents'):
    #     objects = [obj.get('Key') for obj in result.get('Contents') if obj.get('Key')]
    return result

# %% [markdown]
# # Get From SF

# %%
df=pd.read_csv('/Users/fido_josephine/Documents/Risk NBs/Uganda - Marketing_Growth 360 Report - 2025 - Overview Aug 2025.csv')

# %%
# df=df.iloc[:16,:17]
df=df.iloc[:21,:32]
df
# Out:
#                             9/5/2025 August 1 August 2 August 3 August 4  \
# 0                       New Installs      739      711      720      724
# 1                            Sign up      622      645      630      629
# 2                      KYC Completed      234      255      247      227
# 3                        FS_ELIGIBLE       72       78       69       79
# 4        First Disbursement Personal       71       75       55       79
# 5             First Disb.FidoBiz New       10        1        2       11
# 6   First Disb. FidoBiz Migrated New       15        1        3        8
# 7   First Disb. FidoBiz Migrated Old        5        4        0        6
# 8             First Disbursement All       81       76       57       90
# 9                        Cost Growth     $651     $642     $639     $675
# 10                   Cost Marketing      $107     $107     $107     $107
# 11                               CAC    $9.37    $9.87   $13.10    $8.70
# 12                               CPI    $1.03    $1.05    $1.04    $1.08
# 13                               CPL    $1.22    $1.16    $1.19    $1.24
# 14                             CPKYC    $3.24    $2.94    $3.02    $3.45
# 15                   Installs/SignUp      84%      91%      88%      87%
# 16             Sign Up/KYC completed      38%      40%      39%      36%
# 17                   KYC/First Disb.      35%      30%      23%      40%
# 18                    FS/First Disb.      99%      96%      80%     100%
# 19            New install/ First dis      11%      11%       8%      12%
# 20                 SignUp/First dis.      13%      12%       9%      14%
#
#    August 5 August 6 August 7 August 8 August 9  ... August 22 August 23  \
# 0       771      764      922      754      777  ...       705       696
# 1       661      628      772      697      701  ...       634       648
# 2       256      244      290      283      267  ...       266       241
# 3        79       68       87       83       70  ...        79        79
# 4        82       75       83       92       80  ...       101        84
# 5         5        5        3        2        0  ...         3         3
# 6         8        4        6        6        1  ...        14         5
# 7         7        5        3        9        2  ...         2         2
# 8        87       80       86       94       80  ...       104        87
# 9      $607     $588     $718     $559     $567  ...      $614      $189
# 10     $107     $107     $107     $107     $107  ...      $107      $107
# 11    $8.22    $8.70    $9.60    $7.10    $8.44  ...     $6.94     $3.41
# 12    $0.93    $0.91    $0.90    $0.88    $0.87  ...     $1.02     $0.43
# 13    $1.08    $1.11    $1.07    $0.96    $0.96  ...     $1.14     $0.46
# 14    $2.79    $2.85    $2.85    $2.36    $2.53  ...     $2.71     $1.23
# 15      86%      82%      84%      92%      90%  ...       90%       93%
# 16      39%      39%      38%      41%      38%  ...       42%       37%
# 17      34%      33%      30%      33%      30%  ...       39%       36%
# 18     104%     110%      95%     111%     114%  ...      128%      106%
# 19      11%      10%       9%      12%      10%  ...       15%       13%
# 20      13%      13%      11%      13%      11%  ...       16%       13%
#
#    August 24 August 25 August 26 August 27 August 28 August 29 August 30  \
# 0        694       707       711       684       700       703       690
# 1        616       646       647       634       529       627       532
# 2        220       274       262       242       215       234       182
# 3         62        73        68        70        62        54        46
# 4         65        83        83        72        68        57        45
# 5          1         6         8         0        10         2         2
# 6          1         5         3         8        11        14         2
# 7          1         5         4         6         7         9         3
# 8         66        89        91        72        78        59        47
# 9       $587      $597      $557      $599      $603      $535      $568
# 10      $107      $107      $107      $107      $107      $107      $107
# 11    $10.53     $7.92     $7.31     $9.81     $9.11    $10.90    $14.38
# 12     $1.00     $1.00     $0.94     $1.03     $1.02     $0.91     $0.98
# 13     $1.13     $1.09     $1.03     $1.11     $1.34     $1.03     $1.27
# 14     $3.16     $2.57     $2.54     $2.92     $3.31     $2.75     $3.71
# 15       89%       91%       91%       93%       76%       89%       77%
# 16       36%       42%       40%       38%       41%       37%       34%
# 17       30%       32%       35%       30%       36%       25%       26%
# 18      105%      114%      122%      103%      110%      106%       98%
# 19       10%       13%       13%       11%       11%        8%        7%
# 20       11%       14%       14%       11%       15%        9%        9%
#
#    August 31
# 0        568
# 1        535
# 2        204
# 3         48
# 4         62
# 5          1
# 6          1
# 7          4
# 8         63
# 9       $587
# 10      $107
# 11    $11.02
# 12     $1.22
# 13     $1.30
# 14     $3.40
# 15       94%
# 16       38%
# 17       31%
# 18      129%
# 19       11%
# 20       12%
#
# [21 rows x 32 columns]

# %% [markdown]
# ### edit

# %%
new_column_names = df.columns.tolist()
df.columns = range(len(df.columns))

# %%
# Insert a new row at the beginning with the original column names
df.loc[-1] = new_column_names

# %%
df.index = df.index + 1

# %%
df=df.sort_index().transpose()
df.columns = df.iloc[0]
df = df[1:]
df = df.rename(columns={'Cost Growth': 'Cost Digital', 'Cost Marketing ': 'Cost offline '})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace(r'[+\-./]', '', regex=True)
df
# Out:
# 0      952025 new_installs sign_up kyc_completed fs_eligible  \
# 1    August 1          739     622           234          72
# 2    August 2          711     645           255          78
# 3    August 3          720     630           247          69
# 4    August 4          724     629           227          79
# 5    August 5          771     661           256          79
# 6    August 6          764     628           244          68
# 7    August 7          922     772           290          87
# 8    August 8          754     697           283          83
# 9    August 9          777     701           267          70
# 10  August 10          743     656           240          54
# 11  August 11          814     800           287          82
# 12  August 12          761     656           268          67
# 13  August 13          685     650           264          65
# 14  August 14          804     704           255          65
# 15  August 15          752     684           255          61
# 16  August 16          702     632           237          57
# 17  August 17          723     583           233          74
# 18  August 18          792     715           270          78
# 19  August 19          732     665           256          81
# 20  August 20          795     689           274          89
# 21  August 21        1,016     998           389         132
# 22  August 22          705     634           266          79
# 23  August 23          696     648           241          79
# 24  August 24          694     616           220          62
# 25  August 25          707     646           274          73
# 26  August 26          711     647           262          68
# 27  August 27          684     634           242          70
# 28  August 28          700     529           215          62
# 29  August 29          703     627           234          54
# 30  August 30          690     532           182          46
# 31  August 31          568     535           204          48
#
# 0  first_disbursement_personal first_disbfidobiz_new  \
# 1                           71                    10
# 2                           75                     1
# 3                           55                     2
# 4                           79                    11
# 5                           82                     5
# 6                           75                     5
# 7                           83                     3
# 8                           92                     2
# 9                           80                     0
# 10                          59                     0
# 11                          84                    13
# 12                          71                     3
# 13                          49                     2
# 14                          64                     6
# 15                          60                     2
# 16                          55                     1
# 17                          56                     0
# 18                          50                     6
# 19                          98                    14
# 20                          93                     4
# 21                         124                     7
# 22                         101                     3
# 23                          84                     3
# 24                          65                     1
# 25                          83                     6
# 26                          83                     8
# 27                          72                     0
# 28                          68                    10
# 29                          57                     2
# 30                          45                     2
# 31                          62                     1
#
# 0  first_disb_fidobiz_migrated_new first_disb_fidobiz_migrated_old  \
# 1                               15                               5
# 2                                1                               4
# 3                                3                               0
# 4                                8                               6
# 5                                8                               7
# 6                                4                               5
# 7                                6                               3
# 8                                6                               9
# 9                                1                               2
# 10                               3                               4
# 11                               6                               8
# 12                               9                               4
# 13                               6                               4
# 14                               5                               0
# 15                               8                               3
# 16                               4                               1
# 17                               2                               1
# 18                              10                               4
# 19                               6                               3
# 20                              11                               6
# 21                               7                               5
# 22                              14                               2
# 23                               5                               2
# 24                               1                               1
# 25                               5                               5
# 26                               3                               4
# 27                               8                               6
# 28                              11                               7
# 29                              14                               9
# 30                               2                               3
# 31                               1                               4
#
# 0  first_disbursement_all  ...     cac    cpi    cpl  cpkyc installssignup  \
# 1                      81  ...   $9.37  $1.03  $1.22  $3.24            84%
# 2                      76  ...   $9.87  $1.05  $1.16  $2.94            91%
# 3                      57  ...  $13.10  $1.04  $1.19  $3.02            88%
# 4                      90  ...   $8.70  $1.08  $1.24  $3.45            87%
# 5                      87  ...   $8.22  $0.93  $1.08  $2.79            86%
# 6                      80  ...   $8.70  $0.91  $1.11  $2.85            82%
# 7                      86  ...   $9.60  $0.90  $1.07  $2.85            84%
# 8                      94  ...   $7.10  $0.88  $0.96  $2.36            92%
# 9                      80  ...   $8.44  $0.87  $0.96  $2.53            90%
# 10                     59  ...  $11.03  $0.88  $0.99  $2.71            88%
# 11                     97  ...   $7.81  $0.93  $0.95  $2.64            98%
# 12                     74  ...   $9.09  $0.88  $1.03  $2.51            86%
# 13                     51  ...  $12.86  $0.96  $1.01  $2.48            95%
# 14                     70  ...   $9.47  $0.82  $0.94  $2.60            88%
# 15                     62  ...  $10.31  $0.85  $0.93  $2.51            91%
# 16                     56  ...  $11.16  $0.89  $0.99  $2.64            90%
# 17                     56  ...  $11.07  $0.86  $1.06  $2.66            81%
# 18                     56  ...  $11.12  $0.79  $0.87  $2.31            90%
# 19                    112  ...   $5.58  $0.85  $0.94  $2.44            91%
# 20                     97  ...   $7.28  $0.89  $1.02  $2.58            87%
# 21                    131  ...   $5.84  $0.75  $0.77  $1.97            98%
# 22                    104  ...   $6.94  $1.02  $1.14  $2.71            90%
# 23                     87  ...   $3.41  $0.43  $0.46  $1.23            93%
# 24                     66  ...  $10.53  $1.00  $1.13  $3.16            89%
# 25                     89  ...   $7.92  $1.00  $1.09  $2.57            91%
# 26                     91  ...   $7.31  $0.94  $1.03  $2.54            91%
# 27                     72  ...   $9.81  $1.03  $1.11  $2.92            93%
# 28                     78  ...   $9.11  $1.02  $1.34  $3.31            76%
# 29                     59  ...  $10.90  $0.91  $1.03  $2.75            89%
# 30                     47  ...  $14.38  $0.98  $1.27  $3.71            77%
# 31                     63  ...  $11.02  $1.22  $1.30  $3.40            94%
#
# 0  sign_upkyc_completed kycfirst_disb fsfirst_disb new_install_first_dis  \
# 1                   38%           35%          99%                   11%
# 2                   40%           30%          96%                   11%
# 3                   39%           23%          80%                    8%
# 4                   36%           40%         100%                   12%
# 5                   39%           34%         104%                   11%
# 6                   39%           33%         110%                   10%
# 7                   38%           30%          95%                    9%
# 8                   41%           33%         111%                   12%
# 9                   38%           30%         114%                   10%
# 10                  37%           25%         109%                    8%
# 11                  36%           34%         102%                   12%
# 12                  41%           28%         106%                   10%
# 13                  41%           19%          75%                    7%
# 14                  36%           27%          98%                    9%
# 15                  37%           24%          98%                    8%
# 16                  38%           24%          96%                    8%
# 17                  40%           24%          76%                    8%
# 18                  38%           21%          64%                    7%
# 19                  38%           44%         121%                   15%
# 20                  40%           35%         104%                   12%
# 21                  39%           34%          94%                   13%
# 22                  42%           39%         128%                   15%
# 23                  37%           36%         106%                   13%
# 24                  36%           30%         105%                   10%
# 25                  42%           32%         114%                   13%
# 26                  40%           35%         122%                   13%
# 27                  38%           30%         103%                   11%
# 28                  41%           36%         110%                   11%
# 29                  37%           25%         106%                    8%
# 30                  34%           26%          98%                    7%
# 31                  38%           31%         129%                   11%
#
# 0  signupfirst_dis
# 1              13%
# 2              12%
# 3               9%
# 4              14%
# 5              13%
# 6              13%
# 7              11%
# 8              13%
# 9              11%
# 10              9%
# 11             12%
# 12             11%
# 13              8%
# 14             10%
# 15              9%
# 16              9%
# 17             10%
# 18              8%
# 19             17%
# 20             14%
# 21             13%
# 22             16%
# 23             13%
# 24             11%
# 25             14%
# 26             14%
# 27             11%
# 28             15%
# 29              9%
# 30              9%
# 31             12%
#
# [31 rows x 22 columns]

# %%
df.columns = ['report_day'] + df.columns.tolist()[1:]
df['report_day'] = pd.to_datetime(df['report_day'], format='%B %d')
df['report_day'] = df['report_day'].dt.strftime('2025-%m-%d')
df
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 1   2025-08-01          739     622           234          72
# 2   2025-08-02          711     645           255          78
# 3   2025-08-03          720     630           247          69
# 4   2025-08-04          724     629           227          79
# 5   2025-08-05          771     661           256          79
# 6   2025-08-06          764     628           244          68
# 7   2025-08-07          922     772           290          87
# 8   2025-08-08          754     697           283          83
# 9   2025-08-09          777     701           267          70
# 10  2025-08-10          743     656           240          54
# 11  2025-08-11          814     800           287          82
# 12  2025-08-12          761     656           268          67
# 13  2025-08-13          685     650           264          65
# 14  2025-08-14          804     704           255          65
# 15  2025-08-15          752     684           255          61
# 16  2025-08-16          702     632           237          57
# 17  2025-08-17          723     583           233          74
# 18  2025-08-18          792     715           270          78
# 19  2025-08-19          732     665           256          81
# 20  2025-08-20          795     689           274          89
# 21  2025-08-21        1,016     998           389         132
# 22  2025-08-22          705     634           266          79
# 23  2025-08-23          696     648           241          79
# 24  2025-08-24          694     616           220          62
# 25  2025-08-25          707     646           274          73
# 26  2025-08-26          711     647           262          68
# 27  2025-08-27          684     634           242          70
# 28  2025-08-28          700     529           215          62
# 29  2025-08-29          703     627           234          54
# 30  2025-08-30          690     532           182          46
# 31  2025-08-31          568     535           204          48
#
#    first_disbursement_personal first_disbfidobiz_new  \
# 1                           71                    10
# 2                           75                     1
# 3                           55                     2
# 4                           79                    11
# 5                           82                     5
# 6                           75                     5
# 7                           83                     3
# 8                           92                     2
# 9                           80                     0
# 10                          59                     0
# 11                          84                    13
# 12                          71                     3
# 13                          49                     2
# 14                          64                     6
# 15                          60                     2
# 16                          55                     1
# 17                          56                     0
# 18                          50                     6
# 19                          98                    14
# 20                          93                     4
# 21                         124                     7
# 22                         101                     3
# 23                          84                     3
# 24                          65                     1
# 25                          83                     6
# 26                          83                     8
# 27                          72                     0
# 28                          68                    10
# 29                          57                     2
# 30                          45                     2
# 31                          62                     1
#
#    first_disb_fidobiz_migrated_new first_disb_fidobiz_migrated_old  \
# 1                               15                               5
# 2                                1                               4
# 3                                3                               0
# 4                                8                               6
# 5                                8                               7
# 6                                4                               5
# 7                                6                               3
# 8                                6                               9
# 9                                1                               2
# 10                               3                               4
# 11                               6                               8
# 12                               9                               4
# 13                               6                               4
# 14                               5                               0
# 15                               8                               3
# 16                               4                               1
# 17                               2                               1
# 18                              10                               4
# 19                               6                               3
# 20                              11                               6
# 21                               7                               5
# 22                              14                               2
# 23                               5                               2
# 24                               1                               1
# 25                               5                               5
# 26                               3                               4
# 27                               8                               6
# 28                              11                               7
# 29                              14                               9
# 30                               2                               3
# 31                               1                               4
#
#    first_disbursement_all  ...     cac    cpi    cpl  cpkyc installssignup  \
# 1                      81  ...   $9.37  $1.03  $1.22  $3.24            84%
# 2                      76  ...   $9.87  $1.05  $1.16  $2.94            91%
# 3                      57  ...  $13.10  $1.04  $1.19  $3.02            88%
# 4                      90  ...   $8.70  $1.08  $1.24  $3.45            87%
# 5                      87  ...   $8.22  $0.93  $1.08  $2.79            86%
# 6                      80  ...   $8.70  $0.91  $1.11  $2.85            82%
# 7                      86  ...   $9.60  $0.90  $1.07  $2.85            84%
# 8                      94  ...   $7.10  $0.88  $0.96  $2.36            92%
# 9                      80  ...   $8.44  $0.87  $0.96  $2.53            90%
# 10                     59  ...  $11.03  $0.88  $0.99  $2.71            88%
# 11                     97  ...   $7.81  $0.93  $0.95  $2.64            98%
# 12                     74  ...   $9.09  $0.88  $1.03  $2.51            86%
# 13                     51  ...  $12.86  $0.96  $1.01  $2.48            95%
# 14                     70  ...   $9.47  $0.82  $0.94  $2.60            88%
# 15                     62  ...  $10.31  $0.85  $0.93  $2.51            91%
# 16                     56  ...  $11.16  $0.89  $0.99  $2.64            90%
# 17                     56  ...  $11.07  $0.86  $1.06  $2.66            81%
# 18                     56  ...  $11.12  $0.79  $0.87  $2.31            90%
# 19                    112  ...   $5.58  $0.85  $0.94  $2.44            91%
# 20                     97  ...   $7.28  $0.89  $1.02  $2.58            87%
# 21                    131  ...   $5.84  $0.75  $0.77  $1.97            98%
# 22                    104  ...   $6.94  $1.02  $1.14  $2.71            90%
# 23                     87  ...   $3.41  $0.43  $0.46  $1.23            93%
# 24                     66  ...  $10.53  $1.00  $1.13  $3.16            89%
# 25                     89  ...   $7.92  $1.00  $1.09  $2.57            91%
# 26                     91  ...   $7.31  $0.94  $1.03  $2.54            91%
# 27                     72  ...   $9.81  $1.03  $1.11  $2.92            93%
# 28                     78  ...   $9.11  $1.02  $1.34  $3.31            76%
# 29                     59  ...  $10.90  $0.91  $1.03  $2.75            89%
# 30                     47  ...  $14.38  $0.98  $1.27  $3.71            77%
# 31                     63  ...  $11.02  $1.22  $1.30  $3.40            94%
#
#    sign_upkyc_completed kycfirst_disb fsfirst_disb new_install_first_dis  \
# 1                   38%           35%          99%                   11%
# 2                   40%           30%          96%                   11%
# 3                   39%           23%          80%                    8%
# 4                   36%           40%         100%                   12%
# 5                   39%           34%         104%                   11%
# 6                   39%           33%         110%                   10%
# 7                   38%           30%          95%                    9%
# 8                   41%           33%         111%                   12%
# 9                   38%           30%         114%                   10%
# 10                  37%           25%         109%                    8%
# 11                  36%           34%         102%                   12%
# 12                  41%           28%         106%                   10%
# 13                  41%           19%          75%                    7%
# 14                  36%           27%          98%                    9%
# 15                  37%           24%          98%                    8%
# 16                  38%           24%          96%                    8%
# 17                  40%           24%          76%                    8%
# 18                  38%           21%          64%                    7%
# 19                  38%           44%         121%                   15%
# 20                  40%           35%         104%                   12%
# 21                  39%           34%          94%                   13%
# 22                  42%           39%         128%                   15%
# 23                  37%           36%         106%                   13%
# 24                  36%           30%         105%                   10%
# 25                  42%           32%         114%                   13%
# 26                  40%           35%         122%                   13%
# 27                  38%           30%         103%                   11%
# 28                  41%           36%         110%                   11%
# 29                  37%           25%         106%                    8%
# 30                  34%           26%          98%                    7%
# 31                  38%           31%         129%                   11%
#
#    signupfirst_dis
# 1              13%
# 2              12%
# 3               9%
# 4              14%
# 5              13%
# 6              13%
# 7              11%
# 8              13%
# 9              11%
# 10              9%
# 11             12%
# 12             11%
# 13              8%
# 14             10%
# 15              9%
# 16              9%
# 17             10%
# 18              8%
# 19             17%
# 20             14%
# 21             13%
# 22             16%
# 23             13%
# 24             11%
# 25             14%
# 26             14%
# 27             11%
# 28             15%
# 29              9%
# 30              9%
# 31             12%
#
# [31 rows x 22 columns]

# %%
df['cac_incl_branding']=np.nan
df['fsfirst_disb']=np.nan

# %%
df['first_disbursement_fidobiz'] = df['first_disb_fidobiz_migrated_new'] + df['first_disb_fidobiz_migrated_old'] + df['first_disbfidobiz_new']

# %%
# List of columns to keep constant
constant_cols = ['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible', 'first_disbursement_all',
                 'cost_digital', 'cost_offline_', 'cac', 'cac_incl_branding', 'cpi', 'cpl', 'cpkyc', 'installssignup',
                 'sign_upkyc_completed', 'kycfirst_disb', 'fsfirst_disb', 'new_install_first_dis', 'signupfirst_dis',
                 'first_disbursement_personal', 'first_disbursement_fidobiz', 'first_disbfidobiz_new', 
                 'first_disb_fidobiz_migrated_old']

# Identify columns to move (those not in constant_cols)
cols_to_move = [col for col in df.columns if col not in constant_cols]

# Reorganize columns: keep constant columns first, then move the others
df = df[constant_cols + cols_to_move]

# %%
df.head(2)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-08-01          739     622           234          72
# 2  2025-08-02          711     645           255          78
#
#   first_disbursement_all cost_digital cost_offline_    cac  cac_incl_branding  \
# 1                     81         $651          $107  $9.37                NaN
# 2                     76         $642          $107  $9.87                NaN
#
#    ... sign_upkyc_completed kycfirst_disb fsfirst_disb new_install_first_dis  \
# 1  ...                  38%           35%          NaN                   11%
# 2  ...                  40%           30%          NaN                   11%
#
#   signupfirst_dis first_disbursement_personal  first_disbursement_fidobiz  \
# 1             13%                          71                       15510
# 2             12%                          75                         141
#
#   first_disbfidobiz_new first_disb_fidobiz_migrated_old  \
# 1                    10                               5
# 2                     1                               4
#
#   first_disb_fidobiz_migrated_new
# 1                              15
# 2                               1
#
# [2 rows x 24 columns]

# %%
df
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 1   2025-08-01          739     622           234          72
# 2   2025-08-02          711     645           255          78
# 3   2025-08-03          720     630           247          69
# 4   2025-08-04          724     629           227          79
# 5   2025-08-05          771     661           256          79
# 6   2025-08-06          764     628           244          68
# 7   2025-08-07          922     772           290          87
# 8   2025-08-08          754     697           283          83
# 9   2025-08-09          777     701           267          70
# 10  2025-08-10          743     656           240          54
# 11  2025-08-11          814     800           287          82
# 12  2025-08-12          761     656           268          67
# 13  2025-08-13          685     650           264          65
# 14  2025-08-14          804     704           255          65
# 15  2025-08-15          752     684           255          61
# 16  2025-08-16          702     632           237          57
# 17  2025-08-17          723     583           233          74
# 18  2025-08-18          792     715           270          78
# 19  2025-08-19          732     665           256          81
# 20  2025-08-20          795     689           274          89
# 21  2025-08-21        1,016     998           389         132
# 22  2025-08-22          705     634           266          79
# 23  2025-08-23          696     648           241          79
# 24  2025-08-24          694     616           220          62
# 25  2025-08-25          707     646           274          73
# 26  2025-08-26          711     647           262          68
# 27  2025-08-27          684     634           242          70
# 28  2025-08-28          700     529           215          62
# 29  2025-08-29          703     627           234          54
# 30  2025-08-30          690     532           182          46
# 31  2025-08-31          568     535           204          48
#
#    first_disbursement_all cost_digital cost_offline_     cac  \
# 1                      81         $651          $107   $9.37
# 2                      76         $642          $107   $9.87
# 3                      57         $639          $107  $13.10
# 4                      90         $675          $107   $8.70
# 5                      87         $607          $107   $8.22
# 6                      80         $588          $107   $8.70
# 7                      86         $718          $107   $9.60
# 8                      94         $559          $107   $7.10
# 9                      80         $567          $107   $8.44
# 10                     59         $543          $107  $11.03
# 11                     97         $650          $107   $7.81
# 12                     74         $565          $107   $9.09
# 13                     51         $548          $107  $12.86
# 14                     70         $555          $107   $9.47
# 15                     62         $531          $107  $10.31
# 16                     56         $517          $107  $11.16
# 17                     56         $512          $107  $11.07
# 18                     56         $515          $107  $11.12
# 19                    112         $517          $107   $5.58
# 20                     97         $598          $107   $7.28
# 21                    131         $658          $107   $5.84
# 22                    104         $614          $107   $6.94
# 23                     87         $189          $107   $3.41
# 24                     66         $587          $107  $10.53
# 25                     89         $597          $107   $7.92
# 26                     91         $557          $107   $7.31
# 27                     72         $599          $107   $9.81
# 28                     78         $603          $107   $9.11
# 29                     59         $535          $107  $10.90
# 30                     47         $568          $107  $14.38
# 31                     63         $587          $107  $11.02
#
#     cac_incl_branding  ... sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1                 NaN  ...                  38%           35%          NaN
# 2                 NaN  ...                  40%           30%          NaN
# 3                 NaN  ...                  39%           23%          NaN
# 4                 NaN  ...                  36%           40%          NaN
# 5                 NaN  ...                  39%           34%          NaN
# 6                 NaN  ...                  39%           33%          NaN
# 7                 NaN  ...                  38%           30%          NaN
# 8                 NaN  ...                  41%           33%          NaN
# 9                 NaN  ...                  38%           30%          NaN
# 10                NaN  ...                  37%           25%          NaN
# 11                NaN  ...                  36%           34%          NaN
# 12                NaN  ...                  41%           28%          NaN
# 13                NaN  ...                  41%           19%          NaN
# 14                NaN  ...                  36%           27%          NaN
# 15                NaN  ...                  37%           24%          NaN
# 16                NaN  ...                  38%           24%          NaN
# 17                NaN  ...                  40%           24%          NaN
# 18                NaN  ...                  38%           21%          NaN
# 19                NaN  ...                  38%           44%          NaN
# 20                NaN  ...                  40%           35%          NaN
# 21                NaN  ...                  39%           34%          NaN
# 22                NaN  ...                  42%           39%          NaN
# 23                NaN  ...                  37%           36%          NaN
# 24                NaN  ...                  36%           30%          NaN
# 25                NaN  ...                  42%           32%          NaN
# 26                NaN  ...                  40%           35%          NaN
# 27                NaN  ...                  38%           30%          NaN
# 28                NaN  ...                  41%           36%          NaN
# 29                NaN  ...                  37%           25%          NaN
# 30                NaN  ...                  34%           26%          NaN
# 31                NaN  ...                  38%           31%          NaN
#
#    new_install_first_dis signupfirst_dis first_disbursement_personal  \
# 1                    11%             13%                          71
# 2                    11%             12%                          75
# 3                     8%              9%                          55
# 4                    12%             14%                          79
# 5                    11%             13%                          82
# 6                    10%             13%                          75
# 7                     9%             11%                          83
# 8                    12%             13%                          92
# 9                    10%             11%                          80
# 10                    8%              9%                          59
# 11                   12%             12%                          84
# 12                   10%             11%                          71
# 13                    7%              8%                          49
# 14                    9%             10%                          64
# 15                    8%              9%                          60
# 16                    8%              9%                          55
# 17                    8%             10%                          56
# 18                    7%              8%                          50
# 19                   15%             17%                          98
# 20                   12%             14%                          93
# 21                   13%             13%                         124
# 22                   15%             16%                         101
# 23                   13%             13%                          84
# 24                   10%             11%                          65
# 25                   13%             14%                          83
# 26                   13%             14%                          83
# 27                   11%             11%                          72
# 28                   11%             15%                          68
# 29                    8%              9%                          57
# 30                    7%              9%                          45
# 31                   11%             12%                          62
#
#     first_disbursement_fidobiz first_disbfidobiz_new  \
# 1                        15510                    10
# 2                          141                     1
# 3                          302                     2
# 4                         8611                    11
# 5                          875                     5
# 6                          455                     5
# 7                          633                     3
# 8                          692                     2
# 9                          120                     0
# 10                         340                     0
# 11                        6813                    13
# 12                         943                     3
# 13                         642                     2
# 14                         506                     6
# 15                         832                     2
# 16                         411                     1
# 17                         210                     0
# 18                        1046                     6
# 19                        6314                    14
# 20                        1164                     4
# 21                         757                     7
# 22                        1423                     3
# 23                         523                     3
# 24                         111                     1
# 25                         556                     6
# 26                         348                     8
# 27                         860                     0
# 28                       11710                    10
# 29                        1492                     2
# 30                         232                     2
# 31                         141                     1
#
#    first_disb_fidobiz_migrated_old first_disb_fidobiz_migrated_new
# 1                                5                              15
# 2                                4                               1
# 3                                0                               3
# 4                                6                               8
# 5                                7                               8
# 6                                5                               4
# 7                                3                               6
# 8                                9                               6
# 9                                2                               1
# 10                               4                               3
# 11                               8                               6
# 12                               4                               9
# 13                               4                               6
# 14                               0                               5
# 15                               3                               8
# 16                               1                               4
# 17                               1                               2
# 18                               4                              10
# 19                               3                               6
# 20                               6                              11
# 21                               5                               7
# 22                               2                              14
# 23                               2                               5
# 24                               1                               1
# 25                               5                               5
# 26                               4                               3
# 27                               6                               8
# 28                               7                              11
# 29                               9                              14
# 30                               3                               2
# 31                               4                               1
#
# [31 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'first_disbursement_all', 'cost_digital', 'cost_offline_', 'cac',
#        'cac_incl_branding', 'cpi', 'cpl', 'cpkyc', 'installssignup',
#        'sign_upkyc_completed', 'kycfirst_disb', 'fsfirst_disb',
#        'new_install_first_dis', 'signupfirst_dis',
#        'first_disbursement_personal', 'first_disbursement_fidobiz',
#        'first_disbfidobiz_new', 'first_disb_fidobiz_migrated_old',
#        'first_disb_fidobiz_migrated_new'],
#       dtype='object')

# %% [markdown]
# # Upload to S3

# %%
session = boto3.Session(profile_name='gh-dev')

# %%
s3 = session.resource('s3')
my_bucket=s3.Bucket('ug-dev-risk-data')

# %%
# creates empty folder

# %%
# s3_client = session.client('s3')

# # Specify the bucket name
# bucket_name = 'ug-dev-data-tasks'

# # Specify the folder name you want to create (e.g., 'new-folder/')
# folder_name = 'amit-cac-ug/'

# # Create the folder by uploading an empty object
# s3_client.put_object(Bucket=bucket_name, Key=folder_name)

# %%
# upload df as csv

from io import StringIO

# Assume df is your DataFrame
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)  # Convert DataFrame to CSV format in-memory

# %%
file_name='ug_cac_aug_2025.csv'

# %%
# Create an S3 client
s3_client = session.client('s3')

# Specify the bucket and folder names
bucket_name = 'ug-dev-risk-data'
folder_name = 'cac-reports/'   # The folder you created in S3

# Upload the CSV to S3
s3_client.put_object(
    Bucket=bucket_name,
    Key=f'{folder_name}{file_name}',  # Path in S3 including the folder
    Body=csv_buffer.getvalue()  # Get the CSV data from the buffer
)
# Out:
# {'ResponseMetadata': {'RequestId': 'X6FRVNV8VQCBKCG9',
#   'HostId': 'OjAKBTMhFAA8OonZ2ygd8AR6RVjzIcZsEec33fNszW9s8fyscxhjRzuNhh7SP/QB9IC/Xd7BM1ZhYpiFA/Exp29HfBu+r+Wcp3DVX0iIbnI=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'OjAKBTMhFAA8OonZ2ygd8AR6RVjzIcZsEec33fNszW9s8fyscxhjRzuNhh7SP/QB9IC/Xd7BM1ZhYpiFA/Exp29HfBu+r+Wcp3DVX0iIbnI=',
#    'x-amz-request-id': 'X6FRVNV8VQCBKCG9',
#    'date': 'Fri, 05 Sep 2025 10:02:30 GMT',
#    'x-amz-version-id': '2ERFs.r_MPT.klZUs2pTMykl.LhQMgKn',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"c6a118e4c05e4c0829d0265fb673ef00"',
#    'x-amz-checksum-crc64nvme': 'B8sflAH/kBY=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"c6a118e4c05e4c0829d0265fb673ef00"',
#  'ServerSideEncryption': 'AES256',
#  'VersionId': '2ERFs.r_MPT.klZUs2pTMykl.LhQMgKn'}

# %% [markdown]
# # See list of files

# %%
df.head(2)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-08-01          739     622           234          72
# 2  2025-08-02          711     645           255          78
#
#   first_disbursement_all cost_digital cost_offline_    cac  cac_incl_branding  \
# 1                     81         $651          $107  $9.37                NaN
# 2                     76         $642          $107  $9.87                NaN
#
#    ... sign_upkyc_completed kycfirst_disb fsfirst_disb new_install_first_dis  \
# 1  ...                  38%           35%          NaN                   11%
# 2  ...                  40%           30%          NaN                   11%
#
#   signupfirst_dis first_disbursement_personal  first_disbursement_fidobiz  \
# 1             13%                          71                       15510
# 2             12%                          75                         141
#
#   first_disbfidobiz_new first_disb_fidobiz_migrated_old  \
# 1                    10                               5
# 2                     1                               4
#
#   first_disb_fidobiz_migrated_new
# 1                              15
# 2                               1
#
# [2 rows x 24 columns]

# %%
df
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 1   2025-08-01          739     622           234          72
# 2   2025-08-02          711     645           255          78
# 3   2025-08-03          720     630           247          69
# 4   2025-08-04          724     629           227          79
# 5   2025-08-05          771     661           256          79
# 6   2025-08-06          764     628           244          68
# 7   2025-08-07          922     772           290          87
# 8   2025-08-08          754     697           283          83
# 9   2025-08-09          777     701           267          70
# 10  2025-08-10          743     656           240          54
# 11  2025-08-11          814     800           287          82
# 12  2025-08-12          761     656           268          67
# 13  2025-08-13          685     650           264          65
# 14  2025-08-14          804     704           255          65
# 15  2025-08-15          752     684           255          61
# 16  2025-08-16          702     632           237          57
# 17  2025-08-17          723     583           233          74
# 18  2025-08-18          792     715           270          78
# 19  2025-08-19          732     665           256          81
# 20  2025-08-20          795     689           274          89
# 21  2025-08-21        1,016     998           389         132
# 22  2025-08-22          705     634           266          79
# 23  2025-08-23          696     648           241          79
# 24  2025-08-24          694     616           220          62
# 25  2025-08-25          707     646           274          73
# 26  2025-08-26          711     647           262          68
# 27  2025-08-27          684     634           242          70
# 28  2025-08-28          700     529           215          62
# 29  2025-08-29          703     627           234          54
# 30  2025-08-30          690     532           182          46
# 31  2025-08-31          568     535           204          48
#
#    first_disbursement_all cost_digital cost_offline_     cac  \
# 1                      81         $651          $107   $9.37
# 2                      76         $642          $107   $9.87
# 3                      57         $639          $107  $13.10
# 4                      90         $675          $107   $8.70
# 5                      87         $607          $107   $8.22
# 6                      80         $588          $107   $8.70
# 7                      86         $718          $107   $9.60
# 8                      94         $559          $107   $7.10
# 9                      80         $567          $107   $8.44
# 10                     59         $543          $107  $11.03
# 11                     97         $650          $107   $7.81
# 12                     74         $565          $107   $9.09
# 13                     51         $548          $107  $12.86
# 14                     70         $555          $107   $9.47
# 15                     62         $531          $107  $10.31
# 16                     56         $517          $107  $11.16
# 17                     56         $512          $107  $11.07
# 18                     56         $515          $107  $11.12
# 19                    112         $517          $107   $5.58
# 20                     97         $598          $107   $7.28
# 21                    131         $658          $107   $5.84
# 22                    104         $614          $107   $6.94
# 23                     87         $189          $107   $3.41
# 24                     66         $587          $107  $10.53
# 25                     89         $597          $107   $7.92
# 26                     91         $557          $107   $7.31
# 27                     72         $599          $107   $9.81
# 28                     78         $603          $107   $9.11
# 29                     59         $535          $107  $10.90
# 30                     47         $568          $107  $14.38
# 31                     63         $587          $107  $11.02
#
#     cac_incl_branding  ... sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1                 NaN  ...                  38%           35%          NaN
# 2                 NaN  ...                  40%           30%          NaN
# 3                 NaN  ...                  39%           23%          NaN
# 4                 NaN  ...                  36%           40%          NaN
# 5                 NaN  ...                  39%           34%          NaN
# 6                 NaN  ...                  39%           33%          NaN
# 7                 NaN  ...                  38%           30%          NaN
# 8                 NaN  ...                  41%           33%          NaN
# 9                 NaN  ...                  38%           30%          NaN
# 10                NaN  ...                  37%           25%          NaN
# 11                NaN  ...                  36%           34%          NaN
# 12                NaN  ...                  41%           28%          NaN
# 13                NaN  ...                  41%           19%          NaN
# 14                NaN  ...                  36%           27%          NaN
# 15                NaN  ...                  37%           24%          NaN
# 16                NaN  ...                  38%           24%          NaN
# 17                NaN  ...                  40%           24%          NaN
# 18                NaN  ...                  38%           21%          NaN
# 19                NaN  ...                  38%           44%          NaN
# 20                NaN  ...                  40%           35%          NaN
# 21                NaN  ...                  39%           34%          NaN
# 22                NaN  ...                  42%           39%          NaN
# 23                NaN  ...                  37%           36%          NaN
# 24                NaN  ...                  36%           30%          NaN
# 25                NaN  ...                  42%           32%          NaN
# 26                NaN  ...                  40%           35%          NaN
# 27                NaN  ...                  38%           30%          NaN
# 28                NaN  ...                  41%           36%          NaN
# 29                NaN  ...                  37%           25%          NaN
# 30                NaN  ...                  34%           26%          NaN
# 31                NaN  ...                  38%           31%          NaN
#
#    new_install_first_dis signupfirst_dis first_disbursement_personal  \
# 1                    11%             13%                          71
# 2                    11%             12%                          75
# 3                     8%              9%                          55
# 4                    12%             14%                          79
# 5                    11%             13%                          82
# 6                    10%             13%                          75
# 7                     9%             11%                          83
# 8                    12%             13%                          92
# 9                    10%             11%                          80
# 10                    8%              9%                          59
# 11                   12%             12%                          84
# 12                   10%             11%                          71
# 13                    7%              8%                          49
# 14                    9%             10%                          64
# 15                    8%              9%                          60
# 16                    8%              9%                          55
# 17                    8%             10%                          56
# 18                    7%              8%                          50
# 19                   15%             17%                          98
# 20                   12%             14%                          93
# 21                   13%             13%                         124
# 22                   15%             16%                         101
# 23                   13%             13%                          84
# 24                   10%             11%                          65
# 25                   13%             14%                          83
# 26                   13%             14%                          83
# 27                   11%             11%                          72
# 28                   11%             15%                          68
# 29                    8%              9%                          57
# 30                    7%              9%                          45
# 31                   11%             12%                          62
#
#     first_disbursement_fidobiz first_disbfidobiz_new  \
# 1                        15510                    10
# 2                          141                     1
# 3                          302                     2
# 4                         8611                    11
# 5                          875                     5
# 6                          455                     5
# 7                          633                     3
# 8                          692                     2
# 9                          120                     0
# 10                         340                     0
# 11                        6813                    13
# 12                         943                     3
# 13                         642                     2
# 14                         506                     6
# 15                         832                     2
# 16                         411                     1
# 17                         210                     0
# 18                        1046                     6
# 19                        6314                    14
# 20                        1164                     4
# 21                         757                     7
# 22                        1423                     3
# 23                         523                     3
# 24                         111                     1
# 25                         556                     6
# 26                         348                     8
# 27                         860                     0
# 28                       11710                    10
# 29                        1492                     2
# 30                         232                     2
# 31                         141                     1
#
#    first_disb_fidobiz_migrated_old first_disb_fidobiz_migrated_new
# 1                                5                              15
# 2                                4                               1
# 3                                0                               3
# 4                                6                               8
# 5                                7                               8
# 6                                5                               4
# 7                                3                               6
# 8                                9                               6
# 9                                2                               1
# 10                               4                               3
# 11                               8                               6
# 12                               4                               9
# 13                               4                               6
# 14                               0                               5
# 15                               3                               8
# 16                               1                               4
# 17                               1                               2
# 18                               4                              10
# 19                               3                               6
# 20                               6                              11
# 21                               5                               7
# 22                               2                              14
# 23                               2                               5
# 24                               1                               1
# 25                               5                               5
# 26                               4                               3
# 27                               6                               8
# 28                               7                              11
# 29                               9                              14
# 30                               3                               2
# 31                               4                               1
#
# [31 rows x 24 columns]

# %%
df.shape
# Out:
# (31, 24)

# %%
# !/usr/local/bin/aws --profile ug-dev s3 ls s3://'ug-dev-risk-data/cac-reports/'
# Out:
# zsh:1: no such file or directory: /usr/local/bin/aws
