# %% [markdown]
# # Imports

# %%
import boto3

# %%
import pandas as pd
# import mpu

# %%
from mpu import aws

# %%
def list_bucket(bucket_name: str, prefix: str):
    result = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, Delimiter='/')
    # if result.get('Contents'):
    #     objects = [obj.get('Key') for obj in result.get('Contents') if obj.get('Key')]
    return result

# %% [markdown]
# # Load CSV

# %%
path = '/Users/fido_josephine/Documents/Risk NBs/gh_data'
for file in path:
    df=pd.read_csv(file)
    df=df.iloc[:27,:31]
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 path = '/Users/fido_josephine/Documents/Risk NBs/gh_data'
#       2 for file in path:
# ----> 3     df=pd.read_csv(file)
#       4     df=df.iloc[:27,:31]
#
# File ~/Documents/Risk NBs/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Documents/Risk NBs/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Documents/Risk NBs/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Documents/Risk NBs/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Documents/Risk NBs/.venv/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# IsADirectoryError: [Errno 21] Is a directory: '/'

# %%
df=df.iloc[:27,:31]
# df=df.iloc[:18,:17]
df
# Out:
#                                  7/3/2025  June 1  June 2  June 3  June 4  \
# 0                            New Installs   2,818   3,287   4,040   3,667
# 1                                 Sign up   2,148   2,691   3,365   3,060
# 2                           KYC Completed   1,100   1,436   1,742   1,543
# 3                             FS_ELIGIBLE     705     925    1097     964
# 4                  Survey Submitted (Biz)     124     182     194     193
# 5                     Doc Submitted (Biz)      54      72      77      91
# 6             First Disbursement Personal     639     884     959     863
# 7                  First Disb.FidoBiz New       2      13      12      10
# 8        First Disb. Biz New Partnerships       5       3       4       2
# 9        First Disb. FidoBiz Migrated New      14      19      21      24
# 10  First Disb. Biz Migrated New Partners       1       4       4       7
# 11       First Disb. FidoBiz Migrated Old      37      55      47      37
# 12  First Disb. Biz Migrated Old Partners       2       7       4      11
# 13             First Disbursement All New     646     900     975     875
# 14                            Cost Growth  $2,982  $3,354  $3,301  $3,336
# 15                        Cost Marketing     $530    $530    $530    $530
# 16                                    CAC   $5.44   $4.32   $3.93   $4.42
# 17                                    CPI   $1.25   $1.18   $0.95   $1.05
# 18                                    CPL   $1.64   $1.44   $1.14   $1.26
# 19                                  CPKYC   $3.19   $2.70   $2.20   $2.50
# 20                        Installs/SignUp     76%     82%     83%     83%
# 21                  Sign Up/KYC completed     51%     53%     52%     50%
# 22                        KYC/First Disb.     59%     63%     56%     57%
# 23                         FS/First Disb.     92%     97%     89%     91%
# 24                      Survey/Docs (Biz)     44%     40%     40%     47%
# 25                 New install/ First dis     23%     27%     24%     24%
# 26                      SignUp/First dis.     30%     33%     29%     29%
#
#     June 5  June 6  June 7  June 8  June 9  ... June 21 June 22 June 23  \
# 0    4,207   3,233   3,137   2,907   3,314  ...   3,195   2,775   3,730
# 1    3,385   2,349   2,760   2,385   2,905  ...   2,766   2,243   3,245
# 2    1,747   1,265   1,414   1,194   1,472  ...   1,454   1,156   1,610
# 3     1098     795     871     743     904  ...     777     632     875
# 4      242     178     173      86     127  ...     111      91     134
# 5      107      74      75      60     109  ...     117      80     107
# 6      966     765     814     703     860  ...     783     619     765
# 7       14       9       7       6      11  ...      11       4      10
# 8        5       3       3       1       2  ...       4       4       5
# 9       40      57      13      13      24  ...      20      13      24
# 10       4       4       2       1       1  ...       0       2       3
# 11      50      26      29      13      36  ...      22      13      38
# 12       2       2       1       4       5  ...       2       3       2
# 13     985     777     824     710     873  ...     798     627     780
# 14  $3,301  $3,174  $3,082  $3,122  $3,162  ...  $3,124  $3,022  $3,594
# 15    $530    $530    $530    $530    $530  ...    $530    $530    $530
# 16   $3.89   $4.77   $4.38   $5.14   $4.23  ...   $4.58   $5.66   $5.29
# 17   $0.91   $1.15   $1.15   $1.26   $1.11  ...   $1.14   $1.28   $1.11
# 18   $1.13   $1.58   $1.31   $1.53   $1.27  ...   $1.32   $1.58   $1.27
# 19   $2.19   $2.93   $2.55   $3.06   $2.51  ...   $2.51   $3.07   $2.56
# 20     80%     73%     88%     82%     88%  ...     87%     81%     87%
# 21     52%     54%     51%     50%     51%  ...     53%     52%     50%
# 22     56%     61%     58%     59%     59%  ...     55%     54%     48%
# 23     90%     98%     95%     96%     97%  ...    103%     99%     89%
# 24     44%     42%     43%     70%     86%  ...    105%     88%     80%
# 25     23%     24%     26%     24%     26%  ...     25%     23%     21%
# 26     29%     33%     30%     30%     30%  ...     29%     28%     24%
#
#    June 24 June 25 June 26 June 27 June 28 June 29 June 30
# 0    3,934   3,596   4,063   4,155   3,181   3,041   3,947
# 1    3,523   3,224   3,507   3,757   2,759   2,456   3,372
# 2    1,734   1,620   1,740   1,824   1,402   1,263   1,727
# 3      962     908     916     931     700     632     713
# 4      163     166     166     160     126      94     146
# 5      144     140     143     151      88      91     136
# 6      949     887     855     894     698     594     629
# 7       15      15      13      21      12      15      17
# 8        8       5       5       5       3       1       4
# 9       26      24      34      54      18      11      32
# 10       1       3       3       0       0       1       1
# 11      41      48      67      91      56      41      90
# 12       1       1       2       3       3       3       3
# 13     972     907     873     920     713     610     650
# 14  $3,463  $3,367  $3,434  $3,154  $3,090  $3,123  $2,999
# 15    $530    $530    $530    $530    $530    $530    $530
# 16   $4.11   $4.30   $4.54   $4.00   $5.08   $5.99   $5.43
# 17   $1.02   $1.08   $0.98   $0.89   $1.14   $1.20   $0.89
# 18   $1.13   $1.21   $1.13   $0.98   $1.31   $1.49   $1.05
# 19   $2.30   $2.41   $2.28   $2.02   $2.58   $2.89   $2.04
# 20     90%     90%     86%     90%     87%     81%     85%
# 21     49%     50%     50%     49%     51%     51%     51%
# 22     56%     56%     50%     50%     51%     48%     38%
# 23    101%    100%     95%     99%    102%     97%     91%
# 24     88%     84%     86%     94%     70%     97%     93%
# 25     25%     25%     21%     22%     22%     20%     16%
# 26     28%     28%     25%     24%     26%     25%     19%
#
# [27 rows x 31 columns]

# %% [markdown]
# ### edit

# %%
new_column_names = df.columns.tolist()
df.columns = range(len(df.columns))

# %%
# Insert a new row at the beginning with the original column names
df.loc[-1] = new_column_names

# %%
df.index = df.index + 1

# %%
df=df.sort_index().transpose()
df.columns = df.iloc[0]
df = df[1:]
df = df.rename(columns={'Cost Growth': 'Cost Digital', 'Cost Marketing ': 'Cost offline '})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace(r'[+\-./]', '', regex=True)
df
# Out:
# 0    732025 new_installs sign_up kyc_completed fs_eligible  \
# 1    June 1        2,818   2,148         1,100         705
# 2    June 2        3,287   2,691         1,436         925
# 3    June 3        4,040   3,365         1,742        1097
# 4    June 4        3,667   3,060         1,543         964
# 5    June 5        4,207   3,385         1,747        1098
# 6    June 6        3,233   2,349         1,265         795
# 7    June 7        3,137   2,760         1,414         871
# 8    June 8        2,907   2,385         1,194         743
# 9    June 9        3,314   2,905         1,472         904
# 10  June 10        4,257   3,540         1,865        1175
# 11  June 11        3,520   3,191         1,631        1042
# 12  June 12        4,098   3,572         1,858        1166
# 13  June 13        3,679   3,109         1,670        1032
# 14  June 14        3,689   2,912         1,450         885
# 15  June 15        3,080   2,469         1,280         685
# 16  June 16        3,540   2,970         1,629         914
# 17  June 17        4,283   3,577         1,859         988
# 18  June 18        3,659   3,244         1,760         949
# 19  June 19        4,135   3,512         1,947        1064
# 20  June 20        3,419   2,890         1,668         899
# 21  June 21        3,195   2,766         1,454         777
# 22  June 22        2,775   2,243         1,156         632
# 23  June 23        3,730   3,245         1,610         875
# 24  June 24        3,934   3,523         1,734         962
# 25  June 25        3,596   3,224         1,620         908
# 26  June 26        4,063   3,507         1,740         916
# 27  June 27        4,155   3,757         1,824         931
# 28  June 28        3,181   2,759         1,402         700
# 29  June 29        3,041   2,456         1,263         632
# 30  June 30        3,947   3,372         1,727         713
#
# 0  survey_submitted_(biz) doc_submitted_(biz) first_disbursement_personal  \
# 1                     124                  54                         639
# 2                     182                  72                         884
# 3                     194                  77                         959
# 4                     193                  91                         863
# 5                     242                 107                         966
# 6                     178                  74                         765
# 7                     173                  75                         814
# 8                      86                  60                         703
# 9                     127                 109                         860
# 10                    136                 125                        1048
# 11                    113                 104                        1002
# 12                    129                  99                        1037
# 13                    124                  91                         985
# 14                    101                  80                         925
# 15                     79                  61                         605
# 16                    148                 124                         947
# 17                    153                 113                         939
# 18                    152                 140                         928
# 19                    159                 125                         936
# 20                    146                 149                         902
# 21                    111                 117                         783
# 22                     91                  80                         619
# 23                    134                 107                         765
# 24                    163                 144                         949
# 25                    166                 140                         887
# 26                    166                 143                         855
# 27                    160                 151                         894
# 28                    126                  88                         698
# 29                     94                  91                         594
# 30                    146                 136                         629
#
# 0  first_disbfidobiz_new first_disb_biz_new_partnerships  ...    cpi    cpl  \
# 1                      2                               5  ...  $1.25  $1.64
# 2                     13                               3  ...  $1.18  $1.44
# 3                     12                               4  ...  $0.95  $1.14
# 4                     10                               2  ...  $1.05  $1.26
# 5                     14                               5  ...  $0.91  $1.13
# 6                      9                               3  ...  $1.15  $1.58
# 7                      7                               3  ...  $1.15  $1.31
# 8                      6                               1  ...  $1.26  $1.53
# 9                     11                               2  ...  $1.11  $1.27
# 10                     7                               3  ...  $0.90  $1.08
# 11                    15                               2  ...  $1.07  $1.18
# 12                    12                               4  ...  $0.92  $1.06
# 13                     6                               4  ...  $1.05  $1.25
# 14                    11                               5  ...  $1.01  $1.28
# 15                     8                               3  ...  $1.21  $1.51
# 16                     9                               7  ...  $1.13  $1.34
# 17                    11                               5  ...  $0.93  $1.11
# 18                    12                               5  ...  $1.08  $1.22
# 19                    18                               6  ...  $0.95  $1.12
# 20                    11                               2  ...  $1.12  $1.32
# 21                    11                               4  ...  $1.14  $1.32
# 22                     4                               4  ...  $1.28  $1.58
# 23                    10                               5  ...  $1.11  $1.27
# 24                    15                               8  ...  $1.02  $1.13
# 25                    15                               5  ...  $1.08  $1.21
# 26                    13                               5  ...  $0.98  $1.13
# 27                    21                               5  ...  $0.89  $0.98
# 28                    12                               3  ...  $1.14  $1.31
# 29                    15                               1  ...  $1.20  $1.49
# 30                    17                               4  ...  $0.89  $1.05
#
# 0   cpkyc installssignup sign_upkyc_completed kycfirst_disb fsfirst_disb  \
# 1   $3.19            76%                  51%           59%          92%
# 2   $2.70            82%                  53%           63%          97%
# 3   $2.20            83%                  52%           56%          89%
# 4   $2.50            83%                  50%           57%          91%
# 5   $2.19            80%                  52%           56%          90%
# 6   $2.93            73%                  54%           61%          98%
# 7   $2.55            88%                  51%           58%          95%
# 8   $3.06            82%                  50%           59%          96%
# 9   $2.51            88%                  51%           59%          97%
# 10  $2.06            83%                  53%           57%          90%
# 11  $2.31            91%                  51%           62%          98%
# 12  $2.03            87%                  52%           57%          90%
# 13  $2.32            85%                  54%           60%          96%
# 14  $2.58            79%                  50%           65%         106%
# 15  $2.91            80%                  52%           48%          90%
# 16  $2.45            84%                  55%           59%         105%
# 17  $2.13            84%                  52%           51%          97%
# 18  $2.25            89%                  54%           54%         100%
# 19  $2.03            85%                  55%           49%          90%
# 20  $2.29            85%                  58%           55%         102%
# 21  $2.51            87%                  53%           55%         103%
# 22  $3.07            81%                  52%           54%          99%
# 23  $2.56            87%                  50%           48%          89%
# 24  $2.30            90%                  49%           56%         101%
# 25  $2.41            90%                  50%           56%         100%
# 26  $2.28            86%                  50%           50%          95%
# 27  $2.02            90%                  49%           50%          99%
# 28  $2.58            87%                  51%           51%         102%
# 29  $2.89            81%                  51%           48%          97%
# 30  $2.04            85%                  51%           38%          91%
#
# 0  surveydocs_(biz) new_install_first_dis signupfirst_dis
# 1               44%                   23%             30%
# 2               40%                   27%             33%
# 3               40%                   24%             29%
# 4               47%                   24%             29%
# 5               44%                   23%             29%
# 6               42%                   24%             33%
# 7               43%                   26%             30%
# 8               70%                   24%             30%
# 9               86%                   26%             30%
# 10              92%                   25%             30%
# 11              92%                   29%             32%
# 12              77%                   26%             29%
# 13              73%                   27%             32%
# 14              79%                   26%             32%
# 15              77%                   20%             25%
# 16              84%                   27%             32%
# 17              74%                   22%             27%
# 18              92%                   26%             29%
# 19              79%                   23%             27%
# 20             102%                   27%             32%
# 21             105%                   25%             29%
# 22              88%                   23%             28%
# 23              80%                   21%             24%
# 24              88%                   25%             28%
# 25              84%                   25%             28%
# 26              86%                   21%             25%
# 27              94%                   22%             24%
# 28              70%                   22%             26%
# 29              97%                   20%             25%
# 30              93%                   16%             19%
#
# [30 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['732025', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'survey_submitted_(biz)', 'doc_submitted_(biz)',
#        'first_disbursement_personal', 'first_disbfidobiz_new',
#        'first_disb_biz_new_partnerships', 'first_disb_fidobiz_migrated_new',
#        'first_disb_biz_migrated_new_partners',
#        'first_disb_fidobiz_migrated_old',
#        'first_disb_biz_migrated_old_partners', 'first_disbursement_all_new',
#        'cost_digital', 'cost_offline_', 'cac', 'cpi', 'cpl', 'cpkyc',
#        'installssignup', 'sign_upkyc_completed', 'kycfirst_disb',
#        'fsfirst_disb', 'surveydocs_(biz)', 'new_install_first_dis',
#        'signupfirst_dis'],
#       dtype='object', name=0)

# %%
import numpy as np

# %%
df.columns = ['report_day'] + df.columns.tolist()[1:]
df['report_day'] = pd.to_datetime(df['report_day'], format='%B %d')
df['report_day'] = df['report_day'].dt.strftime('2025-%m-%d')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.columns = ['report_day'] + df.columns.tolist()[1:]
#       2 df['report_day'] = pd.to_datetime(df['report_day'], format='%B %d')
#       3 df['report_day'] = df['report_day'].dt.strftime('2025-%m-%d')
#
# NameError: name 'df' is not defined

# %%
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.head(2)
#
# NameError: name 'df' is not defined

# %%
df['new_install_first_dis']=np.nan
df['signupfirst_dis']=np.nan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['new_install_first_dis']=np.nan
#       2 df['signupfirst_dis']=np.nan
#
# NameError: name 'np' is not defined

# %%
df['cac_incl_branding']=np.nan
df['first_disbursement_all']=np.nan
df['fsfirst_disb']=np.nan
df['first_disbursement_fidobiz']=np.nan

# %%
df.columns
# Out:
# Index(['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'survey_submitted_(biz)', 'doc_submitted_(biz)',
#        'first_disbursement_personal', 'first_disbfidobiz_new',
#        'first_disb_biz_new_partnerships', 'first_disb_fidobiz_migrated_new',
#        'first_disb_biz_migrated_new_partners',
#        'first_disb_fidobiz_migrated_old',
#        'first_disb_biz_migrated_old_partners', 'first_disbursement_all_new',
#        'cost_digital', 'cost_offline_', 'cac', 'cpi', 'cpl', 'cpkyc',
#        'installssignup', 'sign_upkyc_completed', 'kycfirst_disb',
#        'fsfirst_disb', 'surveydocs_(biz)', 'new_install_first_dis',
#        'signupfirst_dis', 'cac_incl_branding', 'first_disbursement_all',
#        'first_disbursement_fidobiz'],
#       dtype='object')

# %%
# List of columns to keep constant
constant_cols = ['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible','first_disbursement_all',
                 'cost_digital', 'cost_offline_', 'cac', 'cac_incl_branding', 'cpi', 'cpl', 'cpkyc', 'installssignup',
                 'sign_upkyc_completed', 'kycfirst_disb','fsfirst_disb',  'new_install_first_dis', 'signupfirst_dis',
                 'first_disbursement_personal','first_disbursement_fidobiz', 'first_disbfidobiz_new', 'first_disb_biz_new_partnerships',
       'first_disb_fidobiz_migrated_new','first_disb_fidobiz_migrated_old','first_disb_biz_migrated_old_partners' ]
added_cols = [ 'first_disbursement_all_new', 'surveydocs_(biz)',]

# Identify columns to move (those not in constant_cols)
# cols_to_move = [col for col in df.columns if col not in constant_cols]
# cols_to_move2 = [col for col in cols_to_move if col not in added_cols]


# Reorganize columns: keep constant columns first, then move the others
df = df[constant_cols + added_cols + cols_to_move2]

# %%
df.head(2)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-06-01        2,818   2,148         1,100         705
# 2  2025-06-02        3,287   2,691         1,436         925
#
#    first_disbursement_all cost_digital cost_offline_    cac  \
# 1                     NaN       $2,982          $530  $5.44
# 2                     NaN       $3,354          $530  $4.32
#
#    cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 1                NaN  ...                    124                  54
# 2                NaN  ...                    182                  72
#
#   first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 1                     2                               5
# 2                    13                               3
#
#   first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 1                              14                                    1
# 2                              19                                    4
#
#    first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 1                               37                                     2
# 2                               55                                     7
#
#    first_disbursement_all_new surveydocs_(biz)
# 1                         646              44%
# 2                         900              40%
#
# [2 rows x 31 columns]

# %%
df['first_disbursement_fidobiz'] = df['first_disbfidobiz_new'].astype(int) + df['first_disb_biz_new_partnerships'].astype(int) 
df['first_disbursement_all'] = df['first_disbursement_personal'].astype(int) + df['first_disbursement_fidobiz'].astype(int)

# %%
df.tail(2)
# Out:
#     report_day new_installs sign_up kyc_completed fs_eligible  \
# 29  2025-06-29        3,041   2,456         1,263         632
# 30  2025-06-30        3,947   3,372         1,727         713
#
#     first_disbursement_all cost_digital cost_offline_    cac  \
# 29                     610       $3,123          $530  $5.99
# 30                     650       $2,999          $530  $5.43
#
#     cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 29                NaN  ...                     94                  91
# 30                NaN  ...                    146                 136
#
#    first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 29                    15                               1
# 30                    17                               4
#
#    first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 29                              11                                    1
# 30                              32                                    1
#
#     first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 29                               41                                     3
# 30                               90                                     3
#
#     first_disbursement_all_new surveydocs_(biz)
# 29                         610              97%
# 30                         650              93%
#
# [2 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['report_day', 'new_installs', 'sign_up', 'kyc_completed', 'fs_eligible',
#        'first_disbursement_all', 'cost_digital', 'cost_offline_', 'cac',
#        'cac_incl_branding', 'cpi', 'cpl', 'cpkyc', 'installssignup',
#        'sign_upkyc_completed', 'kycfirst_disb', 'fsfirst_disb',
#        'new_install_first_dis', 'signupfirst_dis',
#        'first_disbursement_personal', 'first_disbursement_fidobiz',
#        'survey_submitted_(biz)', 'doc_submitted_(biz)',
#        'first_disbfidobiz_new', 'first_disb_biz_new_partnerships',
#        'first_disb_fidobiz_migrated_new',
#        'first_disb_biz_migrated_new_partners',
#        'first_disb_fidobiz_migrated_old',
#        'first_disb_biz_migrated_old_partners', 'first_disbursement_all_new',
#        'surveydocs_(biz)'],
#       dtype='object')

# %%
df.to_parquet('june2025_cac.parquet.gzip',
              compression='gzip')

# %% [markdown]
# # Upload to S3

# %%
import boto3

# %%
session = boto3.Session(profile_name='gh-dev')

# %%
s3 = session.resource('s3')
my_bucket=s3.Bucket('gh-dev-risk-data')

# %%
df.shape
# Out:
# (30, 31)

# %%
df.head(5)
# Out:
#    report_day new_installs sign_up kyc_completed fs_eligible  \
# 1  2025-05-01        3,621   3,092         1,583         932
# 2  2025-05-02        3,480   3,004         1,479         918
# 3  2025-05-03        3,153   2,545         1,382         817
# 4  2025-05-04        2,758   2,021         1,029         609
# 5  2025-05-05        3,304   2,687         1,307         815
#
#    first_disbursement_all cost_digital cost_offline_    cac  \
# 1                     898       $3,020          $503  $3.92
# 2                     889       $3,158          $503  $4.12
# 3                     803       $3,074          $503  $4.45
# 4                     601       $3,032          $503  $5.88
# 5                     805       $3,262          $503  $4.68
#
#    cac_incl_branding  ... survey_submitted_(biz) doc_submitted_(biz)  \
# 1                NaN  ...                    161                  93
# 2                NaN  ...                    151                  61
# 3                NaN  ...                    148                  62
# 4                NaN  ...                    107                  44
# 5                NaN  ...                    193                  73
#
#   first_disbfidobiz_new first_disb_biz_new_partnerships  \
# 1                    13                               4
# 2                    18                               3
# 3                     8                               2
# 4                     0                               1
# 5                     9                               1
#
#   first_disb_fidobiz_migrated_new first_disb_biz_migrated_new_partners  \
# 1                              14                                    0
# 2                              69                                    0
# 3                              11                                    0
# 4                               6                                    0
# 5                              26                                    1
#
#    first_disb_fidobiz_migrated_old  first_disb_biz_migrated_old_partners  \
# 1                               49                                     2
# 2                               50                                     3
# 3                               28                                     1
# 4                               21                                     1
# 5                               30                                     1
#
#    first_disbursement_all_new surveydocs_(biz)
# 1                         898              58%
# 2                         889              40%
# 3                         803              42%
# 4                         601              41%
# 5                         805              38%
#
# [5 rows x 31 columns]

# %%
# upload df as csv

from io import StringIO

# Assume df is your DataFrame
csv_buffer = StringIO()
df.to_csv(csv_buffer, index=False)  # Convert DataFrame to CSV format in-memory

# %%
file_name='gh_cac_june_2025.csv'

# %%
# Create an S3 client
s3_client = session.client('s3')

# Specify the bucket and folder names
bucket_name = 'gh-dev-risk-data'
folder_name = 'cac-reports/'  # The folder you created in S3

# Upload the CSV to S3
s3_client.put_object(
    Bucket=bucket_name,
    Key=f'{folder_name}{file_name}',  # Path in S3 including the folder
    Body=csv_buffer.getvalue()  # Get the CSV data from the buffer
)
# Out:
# {'ResponseMetadata': {'RequestId': 'PK1TMDX4FXQ7KR6Z',
#   'HostId': 'VkFTzF2xTa3H8PvUHJ7VXvFOQYac1GOERsYrdvV0MUbPDE7bDyjzM2q8s8vnLWoTAuTso9CcDrDx+khngUagen6v25IFRSn+',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'VkFTzF2xTa3H8PvUHJ7VXvFOQYac1GOERsYrdvV0MUbPDE7bDyjzM2q8s8vnLWoTAuTso9CcDrDx+khngUagen6v25IFRSn+',
#    'x-amz-request-id': 'PK1TMDX4FXQ7KR6Z',
#    'date': 'Thu, 03 Jul 2025 10:58:25 GMT',
#    'x-amz-version-id': 'tjTaDuzuoAz2ZkFC2ioPpk5j2UGOvPX2',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"84182240e6e3883dfd2589394162ad1d"',
#    'x-amz-checksum-crc64nvme': 'l3ee31SO0+4=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"84182240e6e3883dfd2589394162ad1d"',
#  'ServerSideEncryption': 'AES256',
#  'VersionId': 'tjTaDuzuoAz2ZkFC2ioPpk5j2UGOvPX2'}

# %% [markdown]
# # See list of files

# %%
# !/usr/local/bin/aws --profile gh-dev s3 ls s3://'gh-dev-risk-data/cac-reports/'
# Out:
# zsh:1: no such file or directory: /usr/local/bin/aws

# %%
# !/usr/local/bin/aws --profile gh-dev s3 ls s3://'gh-dev-risk-data/fdr-predictions/'
# Out:
# zsh:1: no such file or directory: /usr/local/bin/aws
